# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data

# Stage 1 - Rank 1
stage1rank1 = [19,28,43]

# Stage 1 - Rank 2
stage1rank2 = [27,32,31]

# Stage 1 - Rank 3
stage1rank3 = [44,30,16]

# Stage 2 - Rank 1
stage2rank1 = [13,3,74]

# Stage 2 - Rank 2
stage2rank2 = [50,30,10]

# Stage 2 - Rank 3
stage2rank3 = [27,57,6]

# Stage 3 - Rank 1
stage3rank1 = [8,7,75]

# Stage 3 - Rank 2
stage3rank2 = [62,22,6]

# Stage 3 - Rank 3
stage3rank3 = [20,61,9]

# %% [markdown]
# ## GRAPHS

# %%
labels = ["Generated", "Random", "Real"]

# %%
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')

# %% [markdown]
# ### Stage 1

# %%
generated = [
    stage1rank1[0],
    stage1rank2[0],
    stage1rank3[0]
]

random = [
    stage1rank1[1],
    stage1rank2[1],
    stage1rank3[1]
]

real = [
    stage1rank1[2],
    stage1rank2[2],
    stage1rank3[2]
]

# %%
ind = np.arange(len(generated))
width = 0.2


fig, ax = plt.subplots(figsize=(15,8))
genBar = ax.bar(ind-width, generated, width, label="Generated")
randBar = ax.bar(ind, random, width, label="Random")
realBar = ax.bar(ind+width, real, width, label="Real")


ax.set_ylabel("Number of votes")
ax.set_title("Number of votes for each Rank for Stage 1")
ax.set_xticks(ind)
ax.set_xticklabels(("Rank 1", "Rank 2", "Rank 3"))
ax.legend()

autolabel(genBar)
autolabel(randBar)
autolabel(realBar)

plt.savefig("s1_bar.pdf", quality=100, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(stage1rank1, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title="Percent voted as Number 1 in Stage 1")

plt.savefig("no1_s1_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(stage1rank3, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title='Percent voted as Number 3 in Stage 1')

plt.savefig("no3__s1_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(stage1rank2, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title='Percent voted as Number 2 in Stage 1')

plt.savefig("no2_s1_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Stage 2

# %%
generated = [
    stage2rank1[0],
    stage2rank2[0],
    stage2rank3[0]
]

random = [
    stage2rank1[1],
    stage2rank2[1],
    stage2rank3[1]
]

real = [
    stage2rank1[2],
    stage2rank2[2],
    stage2rank3[2]
]

# %%
ind = np.arange(len(generated))
width = 0.2


fig, ax = plt.subplots(figsize=(15,8))
genBar = ax.bar(ind-width, generated, width, label="Generated")
randBar = ax.bar(ind, random, width, label="Random")
realBar = ax.bar(ind+width, real, width, label="Real")


ax.set_ylabel("Number of votes")
ax.set_title("Number of votes for each Rank for Stage 2")
ax.set_xticks(ind)
ax.set_xticklabels(("Rank 1", "Rank 2", "Rank 3"))
ax.legend()

autolabel(genBar)
autolabel(randBar)
autolabel(realBar)

plt.savefig("s2_bar.pdf", quality=100, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Stage 3

# %%
generated = [
    stage3rank1[0],
    stage3rank2[0],
    stage3rank3[0]
]

random = [
    stage3rank1[1],
    stage3rank2[1],
    stage3rank3[1]
]

real = [
    stage3rank1[2],
    stage3rank2[2],
    stage3rank3[2]
]

# %%
ind = np.arange(len(generated))
width = 0.2


fig, ax = plt.subplots(figsize=(15,8))
genBar = ax.bar(ind-width, generated, width, label="Generated")
randBar = ax.bar(ind, random, width, label="Random")
realBar = ax.bar(ind+width, real, width, label="Real")


ax.set_ylabel("Number of votes")
ax.set_title("Number of votes for each Rank for Stage 3")
ax.set_xticks(ind)
ax.set_xticklabels(("Rank 1", "Rank 2", "Rank 3"))
ax.legend()

autolabel(genBar)
autolabel(randBar)
autolabel(realBar)

plt.savefig("s3_bar.pdf", quality=100, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### All Stages

# %%
generated = [
    stage1rank1[0]+stage2rank1[0]+stage3rank1[0],
    stage1rank2[0]+stage2rank2[0]+stage3rank2[0],
    stage1rank3[0]+stage2rank3[0]+stage3rank3[0]
]

random = [
    stage1rank1[1]+stage2rank1[1]+stage3rank1[1],
    stage1rank2[1]+stage2rank2[1]+stage3rank2[1],
    stage1rank3[1]+stage2rank3[1]+stage3rank3[1]
]

real = [
    stage1rank1[2]+stage2rank1[2]+stage3rank1[2],
    stage1rank2[2]+stage2rank2[2]+stage3rank2[2],
    stage1rank3[2]+stage2rank3[2]+stage3rank3[2]
]


ind = np.arange(len(generated))
width = 0.2


fig, ax = plt.subplots(figsize=(15,8))
genBar = ax.bar(ind-width, generated, width, label="Generated")
randBar = ax.bar(ind, random, width, label="Random")
realBar = ax.bar(ind+width, real, width, label="Real")


ax.set_ylabel("Number of votes")
ax.set_title("Number of votes for each Rank for All Stages")
ax.set_xticks(ind)
ax.set_xticklabels(("Rank 1", "Rank 2", "Rank 3"))
ax.legend()

autolabel(genBar)
autolabel(randBar)
autolabel(realBar)

plt.savefig("allStages_bar.pdf", quality=100, bbox_inches='tight')

plt.show()

# %%
rank1 = [
    stage1rank1[0]+stage2rank1[0]+stage3rank1[0],
    stage1rank1[1]+stage2rank1[1]+stage3rank1[1],
    stage1rank1[2]+stage2rank1[2]+stage3rank1[2],
]

rank2 = [
    stage1rank2[0]+stage2rank2[0]+stage3rank2[0],
    stage1rank2[1]+stage2rank2[1]+stage3rank2[1],
    stage1rank2[2]+stage2rank2[2]+stage3rank2[2],
]

rank3 = [
    stage1rank3[0]+stage2rank3[0]+stage3rank3[0],
    stage1rank3[1]+stage2rank3[1]+stage3rank3[1],
    stage1rank3[2]+stage2rank3[2]+stage3rank3[2],
]

# %%
fig, ax = plt.subplots()
ax.pie(rank1, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title='Percent voted as Number 1 in All Stages')

plt.savefig("no1_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(rank2, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title='Percent voted as Number 2 in All Stages')

plt.savefig("no2_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(rank3, labels=labels, autopct='%1.1f%%')
ax.axis('equal')
ax.set(title='Percent voted as Number 3 in All Stages')

plt.savefig("no3_pi.png", quality=100, bbox_inches='tight')

plt.show()

# %%
total_real = stage1rank1[2]+stage1rank2[2]+stage1rank3[2]+stage2rank1[2]+stage2rank2[2]+stage2rank3[2]+stage3rank1[2]+stage3rank2[2]+stage3rank3[2]
total_sum_real = stage1rank1[2]+stage1rank2[2]*2+stage1rank3[2]*3+stage2rank1[2]+stage2rank2[2]*2+stage2rank3[2]*3+stage3rank1[2]+stage3rank2[2]*2+stage3rank3[2]*3
average_real = total_sum_real / total_real

print(average_real)
# Out:
# 1.4037037037037037

# %%
total_gen = stage1rank1[0]+stage1rank2[0]+stage1rank3[0]+stage2rank1[0]+stage2rank2[0]+stage2rank3[0]+stage3rank1[0]+stage3rank2[0]+stage3rank3[0]
total_sum_gen = stage1rank1[0]+stage1rank2[0]*2+stage1rank3[0]*3+stage2rank1[0]+stage2rank2[0]*2+stage2rank3[0]*3+stage3rank1[0]+stage3rank2[0]*2+stage3rank3[0]*3
average_gen = total_sum_gen / total_gen

print(average_gen)
# Out:
# 2.188888888888889

# %%
total_rand = stage1rank1[1]+stage1rank2[1]+stage1rank3[1]+stage2rank1[1]+stage2rank2[1]+stage2rank3[1]+stage3rank1[1]+stage3rank2[1]+stage3rank3[1]
total_sum_rand = stage1rank1[1]+stage1rank2[1]*2+stage1rank3[1]*3+stage2rank1[1]+stage2rank2[1]*2+stage2rank3[1]*3+stage3rank1[1]+stage3rank2[1]*2+stage3rank3[1]*3
average_rand = total_sum_rand / total_rand

print(average_rand)
# Out:
# 2.4074074074074074

# %%
fix, ax = plt.subplots(figsize=(9,8))
ax.bar(["Real", "Generated", "Random"], [average_real, average_gen, average_rand])
plt.show()
